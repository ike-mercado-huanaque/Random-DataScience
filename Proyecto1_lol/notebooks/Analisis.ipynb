# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk

# %%
import os

path = "C:\\Users\\ikeem\\OneDrive\\Escritorio\\Random-DataScience\\Proyecto1_lol\\Data\\data_by_feat"
nombre_csv = "IkeRator2020-LA2_1321217817.csv"
data_df = pd.read_csv(os.path.join(path,nombre_csv))
if 'Unnamed: 0' in data_df.columns:
    data_df = data_df.drop('Unnamed: 0',axis=1)

# %%
data_df.columns
# Out:
# Index(['name_player', 'id_player', 'championName', 'championId', 'kda',
#        'kills', 'deaths', 'assists', 'goldEarned', 'goldSpent', 'visionScore',
#        'win'],
#       dtype='object')

# %%
data_grp = data_df.groupby(['name_player'])
for name,grp in data_grp:
    sns.pairplot(grp[['kda','goldSpent','visionScore','win']],hue='win',palette={True: 'blue', False: 'red'})
    plt.suptitle(name)
# Out:
# C:\Users\ikeem\AppData\Local\Temp\ipykernel_43288\448781102.py:2: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for name,grp in data_grp:
