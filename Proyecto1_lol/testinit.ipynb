# %%
import sys
sys.path.append('C:\\Users\\ikeem\\OneDrive\\Escritorio\\Random-DataScience\\Proyecto1_lol\\modulos')
import extractdata

# %%
#nombre invocador
input_name = 'the ghold liom  '
#region
input_region = 'la2' 
var = extractdata.playerData(input_name,input_region)

# %%
var.__run__()
# Out:
# F00_match_stats
# Obteniedo estadisticas para 1 partidas
#
# Obteniedo estadisticas para 11 partidas
#
# Obteniedo estadisticas para 21 partidas
#
# Obteniedo estadisticas para 31 partidas
#
# Obteniedo estadisticas para 41 partidas
#
# Obteniedo estadisticas para 51 partidas
#
# Obteniedo estadisticas para 61 partidas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 var.__run__()
#
# File ~\OneDrive\Escritorio\Random-DataScience\Proyecto1_lol\modulos\extractdata.py:153, in playerData.__run__(self)
#     151 if x.startswith('F'):
#     152     print(x)
# --> 153     getattr(self,x)()
#
# File ~\OneDrive\Escritorio\Random-DataScience\Proyecto1_lol\modulos\extractdata.py:94, in playerData.F00_match_stats(self)
#      93 def F00_match_stats(self):
# ---> 94     self.match_stats = get_match_stats(self._LMlist,region,include_teams=False)
#
# ...
